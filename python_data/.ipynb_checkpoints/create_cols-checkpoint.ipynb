# %%
import pandas as pd

# %%
# Criando um data frame através do arquivo csv

df = pd.read_csv('./data/users.csv')

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age
# 0      Glenda.Pyle@gmail.com  firefighter  25.0
# 1     Hollie.Allys@gmail.com       worker  26.0
# 2     Grier.Henrie@gmail.com       doctor  23.0
# 3  Kittie.Strephon@gmail.com       worker  45.0
# 4    Kassey.Prober@gmail.com       worker  45.0

# %%
df['process'] = 'analysis'

# %%
df['new_age'] = df['age'] + 10

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age   process  new_age
# 0      Glenda.Pyle@gmail.com  firefighter  25.0  analysis     35.0
# 1     Hollie.Allys@gmail.com       worker  26.0  analysis     36.0
# 2     Grier.Henrie@gmail.com       doctor  23.0  analysis     33.0
# 3  Kittie.Strephon@gmail.com       worker  45.0  analysis     55.0
# 4    Kassey.Prober@gmail.com       worker  45.0  analysis     55.0

# %%
df['full_name'] = df['firstname'] + ' ' + df['lastname']

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age   process  new_age  \
# 0      Glenda.Pyle@gmail.com  firefighter  25.0  analysis     35.0
# 1     Hollie.Allys@gmail.com       worker  26.0  analysis     36.0
# 2     Grier.Henrie@gmail.com       doctor  23.0  analysis     33.0
# 3  Kittie.Strephon@gmail.com       worker  45.0  analysis     55.0
# 4    Kassey.Prober@gmail.com       worker  45.0  analysis     55.0
#
#          full_name
# 0      Glenda Pyle
# 1     Hollie Allys
# 2     Grier Henrie
# 3  Kittie Strephon
# 4    Kassey Prober

# %%
from datetime import datetime as dt

# %%
df['created_date_time'] = dt.now().strftime('%d/%m/%Y - %H:%M:%S')

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age   process  new_age  \
# 0      Glenda.Pyle@gmail.com  firefighter  25.0  analysis     35.0
# 1     Hollie.Allys@gmail.com       worker  26.0  analysis     36.0
# 2     Grier.Henrie@gmail.com       doctor  23.0  analysis     33.0
# 3  Kittie.Strephon@gmail.com       worker  45.0  analysis     55.0
# 4    Kassey.Prober@gmail.com       worker  45.0  analysis     55.0
#
#          full_name      created_date_time
# 0      Glenda Pyle  24/04/2025 - 11:56:02
# 1     Hollie Allys  24/04/2025 - 11:56:02
# 2     Grier Henrie  24/04/2025 - 11:56:02
# 3  Kittie Strephon  24/04/2025 - 11:56:02
# ...

# %%
df.drop(columns=['new_age'])
# Out:
#      id   firstname  lastname                           email  \
# 0   100      Glenda      Pyle         Glenda.Pyle@yopmail.com
# 1   101      Hollie     Allys        Hollie.Allys@yopmail.com
# 2   102       Grier    Henrie        Grier.Henrie@yopmail.com
# 3   103      Kittie  Strephon     Kittie.Strephon@yopmail.com
# 4   104      Kassey    Prober       Kassey.Prober@yopmail.com
# 5   105        Lusa   Kolnick        Lusa.Kolnick@yopmail.com
# 6   106  Fredericka   Florina  Fredericka.Florina@yopmail.com
# 7   107   Constance    Georgy    Constance.Georgy@yopmail.com
# 8   108       Maria    Concha       Averyl.Concha@yopmail.com
# 9   109        Lily      Uird           Lily.Uird@yopmail.com
# 10  110      Malina   Huggins      Malina.Huggins@yopmail.com
# 11  111      Dorthy    Nisbet       Dorthy.Nisbet@yopmail.com
# 12  112      Tiffie   Joachim      Tiffie.Joachim@yopmail.com
# 13  113      Agathe  Adrienne     Agathe.Adrienne@yopmail.com
# ...
